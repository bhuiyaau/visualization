# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50) #generates integer for 0-49
y = np.random.randint(0,100,50) #generate random int (y axis 0-100)

# %%
fig, ax = plt.subplots(figsize=(5, 3)) #figure size, by inches
ax.scatter(x,y)

# %%
fig,ax = plt.subplots(figsize=(5,3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y)

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.hist(y) #counting the frequencies of the y (reason why x values not included)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout() #displays cleaner

# %%
font1={'family': 'sans-serif','color':'blue','size': 20}
font2={'family':'monospace','color':'green','size':14}

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title('Total growth over time',fontdict=font1) #loc='right' <--- moves the position of the title
ax.set_ylabel('Total growth',fontdict=font2)
ax.set_xlabel('Years since start',fontdict=font2)
fig.tight_layout()

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.scatter(x,y,marker='*',color='indigo')

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y,marker='*',color='indigo',linestyle='--',linewidth=2)

# %%
fig,ax=plt.subplots(figsize=(5,3))
ax.grid(axis='y',color='blue',linewidth=2,linestyle='-.')
ax.plot(x,y,marker='*',markersize=12,color='#7425b9',linestyle='--',linewidth=2,markeredgecolor='#fa9359',markerfacecolor='#000000')

# %%
#Session 2
#1)What information can we learn from this viz?
#2) How about objectivity and neutrality?

#Information we can learn directly from the plot:
#Number of gun killings
#Age of victim of gun killings
#Estimated difference in lifespan due to gun killing

#We also were given websites to different data visualizations

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
  
sns.set_theme(style="darkgrid")
df = sns.load_dataset('iris')
 
# Make default density plot
sns.kdeplot(df['sepal_width'])
plt.show()

# %%
#aesthetic: not very aesthetic but simple
#substantive: only takes one numerical variable as input
#perceptual: simple

# %%
#Session 3
#image manipulation - duplication
#reproducibility --> ASA transparent assumptions, reproducible results, valid interpretations

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y1=np.random.randint(0,100,50)
y2=np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1)
ax.plot(x,y2)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label='Person1')
ax.plot(x,y2, label='Person2')
ax.legend(loc='lower right', frameon=True,shadow=True,fontsize=12,ncol=2)
#frameon= frame around the legend
#fontsize= change font size
#ncol= specify number of columns

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label='Person1')
ax.plot(x,y2, label='Person2')
ax.legend(loc='upper left', bbox_to_anchor=(1,1))
#bbox_to_anchor = moves outside of the graph

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
ax.text(10,95,"This value is important", ha='left', color='red',size=20)
# Out:
# Text(10, 95, 'This value is important')

# %%
fig,ax=plt.subplots()
ax.axis([0,10,0,10])
ax.text(1,5,".Data:(1,5)",transform=ax.transData)
ax.text(0.5,0.1,"Axes:(0.5,0.1)",transform=ax.transAxes)
ax.text(0.2,0.2,"Figure(0.2,0.2)",transform=fig.transFigure)
# Out:
# Text(0.2, 0.2, 'Figure(0.2,0.2)')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10,95),xytext=(20,70), arrowprops=dict(facecolor='black'))
# Out:
# Text(20, 70, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10,95),xytext=(20,94), arrowprops=dict(arrowstyle='wedge',color='hotpink'))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MultipleLocator(16))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
font1= {'family':'serif', 'color':'indigo'}
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label='Person1')
ax.scatter(x,y2, label='Person2')
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!',fontsize=18,fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y1)
ax.plot(x,y2)

# %%
#FAIR pricinples - findability, accessibility, interoperability, resuability

# %%
#Session 4
#alt-text: two scientists in discussion

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x1=np.arange(50)
y1=np.random.randint(0,75,50)
x2=np.array(["luffy", "Zoro", "Nami","Usopp", "Sanji"])
y2=np.array([110,180,240,99,220])

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,nrows=1,figsize=(7,3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
ax1.scatter(x1,y1,marker='*',color='indigo')
ax2.bar(x2,y2,color='orange')
# Out:
# <BarContainer object of 5 artists>

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,nrows=1,figsize=(7,3))
ax1.scatter(x1,y1)
ax1.annotate("This is important",xy=(10,60),xytext=(20,60),arrowprops=dict(facecolor='black'))
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],['ax2', 'ax3']],figsize=(7.4, 5),layout="constrained")
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
x=np.array(["Luffy", "Zoro", "Nami","Usopp", "Sanji"])
y1=np.array([110,180,240,99,220])
y2=np.array([170,100,90,120,50])
#define our figure and axes (just one this time)
fig,ax=plt.subplots(figsize=(7,3))

#now call both bar and plot elements on the same axes (ax)
ax.bar(x,y1, color="indigo")
ax.plot(x,y2, color="red")

# %%
y2_sd=np.std(y2)

# %%
fig,ax=plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')

# %%
fig,ax=plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')
ax.errorbar(x,y2,yerr=y2_sd,fmt='o-',ecolor='indigo',elinewidth=4,capsize=6,capthick=4,errorevery=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images
url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"
headers = {"User-Agent": "Mozilla/5.0","Accept": "image/*,*/*;q=0.8","Referer": "https://en.wikipedia.org/"}
response = requests.get(url, headers=headers)
image_file = BytesIO(response.content)
image = Image.open(image_file)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x426>

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")
ax_image = fig.add_axes([0.1,0.11,0.15,0.35])
ax_image.imshow(image)
ax_image.axis('off')
# Out:
# (np.float64(-0.5), np.float64(219.5), np.float64(425.5), np.float64(-0.5))

# %%
#Session 5
#data viz are rhetorical, what data are we seeing?

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips=sns.load_dataset("tips")
print(tips)
sns.lineplot(data=tips,x='total_bill',y='tip')
tipgraph = sns.lineplot(data=tips, x='total_bill', y='tip', color='hotpink',linestyle='--',linewidth=3, marker='o',markerfacecolor='indigo')
tipgraph.set(title='Tips vs. Total Bill', xlabel='Total Bill ($)', ylabel='Tip Amount ($)')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph=sns.scatterplot(data=tips, x='total_bill', y='tip', style ='time', hue='day', palette = ['purple','hotpink','deepskyblue','yellowgreen'])
tipgraph.set(title='Tips vs. Total Bill',xlabel='Total Bill($)', ylabel='Tip Amount($)')
# Make 'day' and 'time' headers bold
for text in tipgraph.get_legend().get_texts():
    if text.get_text() in ['day', 'time']:
        text.set_fontweight('bold')
        text.set_fontsize(11)

# %%
sns.pairplot(data=tips,hue='day')

# %%
daysplot = sns.relplot(data=tips, x='total_bill', y='tip', hue='sex', col='day', kind='scatter', col_wrap=2)

# %%
#activity: comparing data visualizations
#left side gives specific understanding on the bar charts, but right side allows an interactive opportunity to pinpoint specific information
#interactive: gendered language in teacher reviews, immediate change with transitional changes (some slight shift in x and y axis due to new data points and adjust slightly as needed)

# %%
import plotly.graph_objects as go
from wordcloud import WordCloud
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
graph=go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1))

graph.update_layout(title='Pirate Scores', xaxis_title='Pirates', yaxis_title='Score')

#graph.write_html("pirategraph.html")

# %%
graph=go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers', marker=dict(size=15, color='hotpink', opacity=1, line=dict(width=5, color='purple'))))
graph.update_layout(title='Interactive Pirate Plot', xaxis_title= 'Pirates', yaxis_title= 'Scores', width=500, height=500)

# %%
df = pd.read_csv("/Users/Aunima Bhuiya/OneDrive - University of Toronto/Documents/DSI training/visualization/02_activities/assignments/movie_quotes.csv")
print(df)
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
text = "".join(each for each in df.quote)
wordcloud = WordCloud(background_color='white', colormap='inferno').generate(text)

fig, ax = plt.subplots(figsize=(7,3))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2_unweighted([A, B], set_labels=('Fruits', 'Pies'), set_colors=("blue", "red"), alpha=0.5)

diagram.get_label_by_id("10").set_text("\n".join(A-B))
diagram.get_label_by_id("11").set_text("\n".join(A&B))
diagram.get_label_by_id("01").set_text("\n".join(B-A))
